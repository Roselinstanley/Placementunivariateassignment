# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("PrePlacement.csv")
quan=[]
qual=[]
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df=pd.DataFrame(dataset)
dfid=pd.DataFrame(dataset['sl_no'])

# %%
df=df.drop(["sl_no"],axis=1)
dataset=df

# %%
#Splitting numerical and categorical data
from Univariateplacement import univar
u=univar(dataset)
qual,quan=u.quanqual()

# %%
dataset.isnull().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
from Freqnorm import Freqnorm
f=Freqnorm(dataset)
for cname in quan:   
    freq,skewness,kurtosis,variance,std=f.frequency(cname)     
    print("\n\n",cname,"\n\n")
    print(freq)
    print("\n\nskewness value of",cname,"=",skewness)
    print("\n\nKurtosis value of",cname,"=",kurtosis)
    print("\n\nVariance value of",cname,"=",variance)
    print("\n\nSD value of",cname,"=",std)
# Out:
#  ssc_p
#
#
#      Unique Values  Frequency  Relative Frequency       CRF
# 0            62.00         11            0.106796  0.106796
# 1            63.00         10            0.097087  0.203883
# 2            67.00          9            0.087379  0.291262
# 3            52.00          9            0.087379  0.378641
# 4            73.00          9            0.087379  0.466019
# ..             ...        ...                 ...       ...
# 98           69.70          1            0.009709  2.048544
# 99           80.92          1            0.009709  2.058252
# 100          83.00          1            0.009709  2.067961
# 101          86.50          1            0.009709  2.077670
# 102          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]
#
#
# skewness value of ssc_p = -0.13264949031456927
#
#
# Kurtosis value of ssc_p = -0.6075102066986688
#
#
# Variance value of ssc_p = 117.22837673549229
#
#
# SD value of ssc_p = 10.827205398231452
#
#
#  hsc_p
#
# ...

# %%
f.cal_PDF(quan)
# Out:
# Enter the start range,endrange,no for PDF ssc_p
#  60
#  90
#  75
# C:\Users\Admin\Desktop\AI\Univariate\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of ssc_p  between the range (60,90):(0.7443953816078211,74.43953816078212)0.7395348837209302
# Enter the start range,endrange,no for PDF hsc_p
#  50
#  85
#  70
# C:\Users\Admin\Desktop\AI\Univariate\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
f.std_normal(quan)
# Out:
# The Z_SCORE plot of ssc_p
# The Z_SCORE plot of hsc_p
# The Z_SCORE plot of degree_p
# The Z_SCORE plot of etest_p
# The Z_SCORE plot of mba_p
# The Z_SCORE plot of salary
#       Z_score
# 0    0.481584
# 1    0.015867
# 2    0.348522
# 3   -1.314753
# 4    1.512815
# ..        ...
# 210  1.346487
# 211  0.514849
# 212  0.647911
# 213  0.042479
# 214 -1.314753
#
# [215 rows x 1 columns]
