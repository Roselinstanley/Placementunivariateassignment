# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Placement.csv")
Lesser=[]
Greater=[]
quan=[]
qual=[]
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Assigning dataset to dataframe for Dropping the id column which is not necessary for analysis
df=pd.DataFrame(dataset)
dfid=pd.DataFrame(dataset['sl_no'])

# %%
df=df.drop(["sl_no"],axis=1)
dataset=df

# %%
#Splitting numerical and categorical data
from Univariateplacement import univar
u=univar(dataset)
qual,quan=u.quanqual()

# %%
#Finding the null values
dataset.isnull().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#single column replacement
dataset.fillna(0,inplace=True) #Inplace has been given because we are not assigning to any variable #0 because the student are not placed so salary is 0
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Inserting the id column which has been dropped initially
df.insert(0,"sl_no",dfid)
dataset=df

# %%
# saving preprocessed data to new csv file
dataset.to_csv("PrePlacement.csv",index=False)

# %%
#Reading Preprocessed CSV file
dataset=pd.read_csv("PrePlacement.csv") #Reading Preprocessed CSV file

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
from Univariateplacement import univar
u=univar(dataset)
centraluni=u.centraltendency()

# %%
centraluni
# Out:
#              ssc_p      hsc_p   degree_p    etest_p      mba_p         salary
# Mean     67.303395  66.333163  66.370186  72.100558  62.278186  198702.325581
# Median        67.0       65.0       66.0       71.0       62.0       240000.0
# Mode          62.0       63.0       65.0       60.0       56.7            0.0
# Q1:25         60.6       60.9       61.0       60.0     57.945            0.0
# Q2:50         67.0       65.0       66.0       71.0       62.0       240000.0
# Q3:75         75.7       73.0       72.0       83.5     66.255       282500.0
# Q4:100        89.4       97.7       91.0       98.0      77.89       940000.0
# IQR           15.1       12.1       11.0       23.5       8.31       282500.0
# 1.5*IQR      22.65      18.15       16.5      35.25     12.465       423750.0
# Lesser       37.95      42.75       44.5      24.75      45.48      -423750.0
# Greater      98.35      91.15       88.5     118.75      78.72       706250.0
# ...

# %%
Lesser,Greater=u.outlierscheck()

# %%
Lesser
# Out:
# ['hsc_p']

# %%
Greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
dataset=u.replacingoutliers()

# %%
u1=univar(dataset)
centraluni=u1.centraltendency()
Lesser,Greater=u1.outlierscheck()

# %%
centraluni
# Out:
#              ssc_p      hsc_p   degree_p    etest_p      mba_p         salary
# Mean     67.303395  66.334744  66.358558  72.100558  62.278186  197615.116279
# Median        67.0       65.0       66.0       71.0       62.0       240000.0
# Mode          62.0       63.0       65.0       60.0       56.7            0.0
# Q1:25         60.6       60.9       61.0       60.0     57.945            0.0
# Q2:50         67.0       65.0       66.0       71.0       62.0       240000.0
# Q3:75         75.7       73.0       72.0       83.5     66.255       282500.0
# Q4:100        89.4      91.15       88.5       98.0      77.89       706250.0
# IQR           15.1       12.1       11.0       23.5       8.31       282500.0
# 1.5*IQR      22.65      18.15       16.5      35.25     12.465       423750.0
# Lesser       37.95      42.75       44.5      24.75      45.48      -423750.0
# Greater      98.35      91.15       88.5     118.75      78.72       706250.0
# ...

# %%
Lesser
# Out:
# []

# %%
Greater
# Out:
# []

# %%
# saving preprocessed data to new csv file
dataset.to_csv("PrePlacement.csv",index=False)

# %%
centraluni=u.centraltendency()
# Out:
# C:\Users\Admin\Desktop\AI\Univariate\Univariateplacement.py:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   centraluni[cname]["Mean"]=self.dataset[cname].mean()
# ...

# %%
centraluni
# Out:
#              ssc_p      hsc_p   degree_p    etest_p      mba_p         salary
# Mean     67.303395  66.334744  66.358558  72.100558  62.278186  197615.116279
# Median        67.0       65.0       66.0       71.0       62.0       240000.0
# Mode          62.0       63.0       65.0       60.0       56.7            0.0
# Q1:25         60.6       60.9       61.0       60.0     57.945            0.0
# Q2:50         67.0       65.0       66.0       71.0       62.0       240000.0
# Q3:75         75.7       73.0       72.0       83.5     66.255       282500.0
# Q4:100        89.4      91.15       88.5       98.0      77.89       706250.0
# IQR           15.1       12.1       11.0       23.5       8.31       282500.0
# 1.5*IQR      22.65      18.15       16.5      35.25     12.465       423750.0
# Lesser       37.95      42.75       44.5      24.75      45.48      -423750.0
# Greater      98.35      91.15       88.5     118.75      78.72       706250.0
# ...
